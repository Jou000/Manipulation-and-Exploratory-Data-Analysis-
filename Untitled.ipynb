# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
STATE = pd.read_table('states_all.csv', sep = ',', header = 0)

# %%
print(type(STATE))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(STATE.shape)
# Out:
# (1492, 25)

# %%
print(STATE.head())
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %%
print(STATE.columns)
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'GRADES_PK_G', 'GRADES_KG_G',
#        'GRADES_4_G', 'GRADES_8_G', 'GRADES_12_G', 'GRADES_1_8_G',
#        'GRADES_9_12_G', 'GRADES_ALL_G', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')

# %%
print(STATE.dtypes)
# Out:
# PRIMARY_KEY                      object
# STATE                            object
# YEAR                              int64
# ENROLL                          float64
# TOTAL_REVENUE                   float64
# FEDERAL_REVENUE                 float64
# STATE_REVENUE                   float64
# LOCAL_REVENUE                   float64
# TOTAL_EXPENDITURE               float64
# INSTRUCTION_EXPENDITURE         float64
# SUPPORT_SERVICES_EXPENDITURE    float64
# OTHER_EXPENDITURE               float64
# CAPITAL_OUTLAY_EXPENDITURE      float64
# GRADES_PK_G                     float64
# GRADES_KG_G                     float64
# GRADES_4_G                      float64
# GRADES_8_G                      float64
# GRADES_12_G                     float64
# GRADES_1_8_G                    float64
# GRADES_9_12_G                   float64
# GRADES_ALL_G                    float64
# AVG_MATH_4_SCORE                float64
# AVG_MATH_8_SCORE                float64
# ...

# %%
print(STATE.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492 entries, 0 to 1491
# Data columns (total 25 columns):
# PRIMARY_KEY                     1492 non-null object
# STATE                           1492 non-null object
# YEAR                            1492 non-null int64
# ENROLL                          1229 non-null float64
# TOTAL_REVENUE                   1280 non-null float64
# FEDERAL_REVENUE                 1280 non-null float64
# STATE_REVENUE                   1280 non-null float64
# LOCAL_REVENUE                   1280 non-null float64
# TOTAL_EXPENDITURE               1280 non-null float64
# INSTRUCTION_EXPENDITURE         1280 non-null float64
# SUPPORT_SERVICES_EXPENDITURE    1280 non-null float64
# OTHER_EXPENDITURE               1229 non-null float64
# CAPITAL_OUTLAY_EXPENDITURE      1280 non-null float64
# GRADES_PK_G                     1319 non-null float64
# GRADES_KG_G                     1360 non-null float64
# ...

# %%
STATE.isna().sum()*100/STATE.shape[0]
# Out:
# PRIMARY_KEY                      0.000000
# STATE                            0.000000
# YEAR                             0.000000
# ENROLL                          17.627346
# TOTAL_REVENUE                   14.209115
# FEDERAL_REVENUE                 14.209115
# STATE_REVENUE                   14.209115
# LOCAL_REVENUE                   14.209115
# TOTAL_EXPENDITURE               14.209115
# INSTRUCTION_EXPENDITURE         14.209115
# SUPPORT_SERVICES_EXPENDITURE    14.209115
# OTHER_EXPENDITURE               17.627346
# CAPITAL_OUTLAY_EXPENDITURE      14.209115
# GRADES_PK_G                     11.595174
# GRADES_KG_G                      8.847185
# GRADES_4_G                       8.780161
# GRADES_8_G                       8.780161
# GRADES_12_G                      8.780161
# GRADES_1_8_G                     8.780161
# GRADES_9_12_G                    8.780161
# GRADES_ALL_G                    11.595174
# AVG_MATH_4_SCORE                64.075067
# ...

# %% [raw]
# Regardez rapidement ce qui se passe dans les données. Sur ecan voir deux principaux groupes de données:
#
# 1-revenue and expenditure
# 2-exams
# 3-La corrélation entre revenue/expenditure ET grades suggère qu'il y a plus d'étudiants qu'il n'y a plus de manie pour l'État pour eux.

# %%
corr = STATE.corr()
fig, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corr, annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [raw]
# L'influence du nom de l'État sur les revenus :

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.violinplot(x="TOTAL_REVENUE", y="STATE", data=STATE)

# %% [raw]
# - Prenons maintenant TOTAL_REVENUE / GRADES_ALL_G ce qui signifie que nous avons plus d'égalité, mais pas parfait.

# %%
STATE['average_reveneue']=STATE['TOTAL_REVENUE']/STATE['GRADES_ALL_G']
STATE['average_expenditure']=STATE['TOTAL_EXPENDITURE']/STATE['GRADES_ALL_G']

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.violinplot(x="average_reveneue", y="STATE", data=STATE[STATE.STATE!='VIRGINIA'])

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.violinplot(x="average_expenditure", y="STATE", data=STATE[STATE.STATE!='VIRGINIA'])

# %% [raw]
# - Regardons l'influence de l'argent sur AVG_MATH_4_SCORE et AVG_READING_8_SCORE

# %%
sns.jointplot("average_expenditure", "AVG_MATH_4_SCORE", data=STATE, kind="reg")

# %%
sns.jointplot("TOTAL_REVENUE", "AVG_MATH_4_SCORE", data=STATE, kind="reg")

# %%
sns.jointplot("average_expenditure", "AVG_READING_8_SCORE", data=STATE, kind="reg")

# %%
sns.jointplot("TOTAL_REVENUE", "AVG_READING_8_SCORE", data=STATE, kind="reg")

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# - Il semble que cela fasse une différence si l'on calcule de l'argent pour tous les étudiants et tout en faisant la moyenne pour chaque étudiant.

# %% [raw]
# Création d'un modèle pour AVG_MATH_4_SCORE ...

# %%
df1=STATE.drop(['PRIMARY_KEY','AVG_MATH_8_SCORE','AVG_READING_4_SCORE','AVG_READING_8_SCORE','ENROLL'],axis=1)
df2=df1.dropna()
df3 = pd.get_dummies(df2, columns=['STATE'])
df4=(df3-df3.mean())/df3.std()

# %%
y=df4.loc[:,'AVG_MATH_4_SCORE'].values
X=df4.drop(['AVG_MATH_4_SCORE'],axis=1).loc[:,:].values

# %%
print(X.shape,' ',y.shape)
# Out:
# (439, 71)   (439,)

# %%
rf=RandomForestRegressor()

parameters = {'n_estimators': [4, 6, 9], 
              'max_features': ['log2', 'sqrt','auto'], 
              'max_depth': [2, 3, 5, 10], 
              'min_samples_split': [2, 3, 5],
              'min_samples_leaf': [1,5,8]
             }

# Run the grid search
grid_obj = GridSearchCV(rf, parameters, cv=5)
grid_obj = grid_obj.fit(X, y)

# Set the clf to the best combination of parameters
rf = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
print('Params ',rf)
print('Score ',rf.score(X, y))
# Out:
# Params  RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=3,
#                       min_weight_fraction_leaf=0.0, n_estimators=9, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False)
# Score  0.928877137618866

# %% [raw]
# Il est difficile d'adapter X et y parce que X est multicolonne, donc j'adapte la redirection Y et les données y - cela devrait être une ligne droite.

# %%
Y_rf=rf.predict(X)
plt.plot(Y_rf, y, 'ro')
plt.show()

# %%
feature_importances_rf = pd.DataFrame(rf.feature_importances_,
                                   index = df4.drop(['AVG_MATH_4_SCORE'],axis=1).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances_rf.head()
# Out:
#                      importance
# YEAR                   0.466334
# average_expenditure    0.083207
# average_reveneue       0.076380
# GRADES_ALL_G           0.050626
# GRADES_4_G             0.042316

# %%
from sklearn.linear_model import Lasso, ElasticNet
clf = Lasso()

parameters = {'alpha': [0.00001,0.0001,0.001, 0.01],
              'tol': [0.00001,0.0001,0.001, 0.01]
             }

# Run the grid search
grid_obj = GridSearchCV(clf, parameters, cv=5)
grid_obj = grid_obj.fit(X, y)

# Set the clf to the best combination of parameters
clf = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
print('Params ',clf)
print('Score ',clf.score(X, y))
# Out:
# Params  Lasso(alpha=1e-05, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=1e-05, warm_start=False)
# Score  0.8976125612525898

# %%
Y_clf=clf.predict(X)
plt.plot(Y_clf, y, 'ro')
plt.show()

# %%
feature_importances_clf = pd.DataFrame(clf.coef_,
                                   index = df4.drop(['AVG_MATH_4_SCORE'],axis=1).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances_clf.head(10)
# Out:
#                             importance
# GRADES_8_G                    2.245814
# GRADES_9_12_G                 1.910244
# GRADES_KG_G                   0.801522
# YEAR                          0.569154
# CAPITAL_OUTLAY_EXPENDITURE    0.305486
# LOCAL_REVENUE                 0.203219
# STATE_NEW_HAMPSHIRE           0.159778
# STATE_MASSACHUSETTS           0.144108
# INSTRUCTION_EXPENDITURE       0.136336
# OTHER_EXPENDITURE             0.126914

# %%
eln = ElasticNet()

parameters = {'alpha': [0.00001,0.0001,0.001, 0.01],
              'l1_ratio': [0.0001,0.001,0.01, 0.1],
              'tol': [0.00001,0.0001,0.001, 0.01],
              'max_iter': [1000,2000,5000, 10000],
             }

# Run the grid search
grid_obj = GridSearchCV(eln, parameters, cv=5)
grid_obj = grid_obj.fit(X, y)

# Set the clf to the best combination of parameters
eln = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
print('Params ',eln)
print('Score ',eln.score(X, y))
# Out:
# Params  ElasticNet(alpha=1e-05, copy_X=True, fit_intercept=True, l1_ratio=0.0001,
#            max_iter=2000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=1e-05, warm_start=False)
# Score  0.8988904514116126

# %%
Y_eln=eln.predict(X)
plt.plot(Y_eln, y, 'ro')
plt.show()

# %% [raw]
# -La valeur la plus basse et la plus élevée sont mieux prédites par Random Forest, les moyennes sont similaires pour tous les modèles.

# %%
fig, ax = plt.subplots(figsize=(15, 15))
plt.plot(Y_eln, y, 'ro',label='Elastic Net')#red Elastic Net
plt.plot(Y_clf, y, 'bs',label='Lasso')#blue Lasso
plt.plot(Y_rf, y, 'g^',label='Random Forest')#green Random Forest
plt.plot([-5,2],[-5,2])#PREDICTION LIKE IT SHOUD BE
plt.legend()
plt.show()

# %%
feature_importances_eln = pd.DataFrame(eln.coef_,
                                   index = df4.drop(['AVG_MATH_4_SCORE'],axis=1).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances_eln.head(10)
# Out:
#                             importance
# GRADES_9_12_G                 2.540822
# GRADES_8_G                    2.468564
# GRADES_KG_G                   1.025890
# YEAR                          0.575874
# INSTRUCTION_EXPENDITURE       0.349460
# CAPITAL_OUTLAY_EXPENDITURE    0.331944
# LOCAL_REVENUE                 0.210306
# STATE_NEW_HAMPSHIRE           0.167708
# STATE_MASSACHUSETTS           0.146731
# OTHER_EXPENDITURE             0.140383

# %% [raw]
# -Influence du Temps:

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.lineplot(x="YEAR", y="AVG_MATH_4_SCORE", data=STATE)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.boxplot(x="AVG_MATH_4_SCORE", y="STATE", data=STATE)

# %%
states=STATE.groupby(['STATE']).mean()
normalized_STATE=(states-states.mean())/states.std()
fig, ax = plt.subplots(figsize=(15, 15))
normalized_STATE['AVG_MATH_4_SCORE'].plot(kind='bar');

# %% [raw]
# Création d'un modèle pour AVG_READING_8_SCORE   ...

# %%
df1=STATE.drop(['PRIMARY_KEY','AVG_MATH_4_SCORE','AVG_MATH_8_SCORE','AVG_READING_4_SCORE','ENROLL'],axis=1)
df2=df1.dropna()
df3 = pd.get_dummies(df2, columns=['STATE'])
df4=(df3-df3.mean())/df3.std()

# %%
y=df4.loc[:,'AVG_READING_8_SCORE'].values
X=df4.drop(['AVG_READING_8_SCORE'],axis=1).loc[:,:].values

# %%
print(X.shape,' ',y.shape)
# Out:
# (436, 71)   (436,)

# %%
rf=RandomForestRegressor()

parameters = {'n_estimators': [4, 6, 9], 
              'max_features': ['log2', 'sqrt','auto'], 
              'max_depth': [2, 3, 5, 10], 
              'min_samples_split': [2, 3, 5],
              'min_samples_leaf': [1,5,8]
             }

# Run the grid search
grid_obj = GridSearchCV(rf, parameters, cv=5)
grid_obj = grid_obj.fit(X, y)

# Set the clf to the best combination of parameters
rf = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
print('Params ',rf)
print('Score ',rf.score(X, y))
# Out:
# Params  RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=8, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=6, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False)
# Score  0.08480441924470028

# %%
Y_rf=rf.predict(X)
plt.plot(Y_rf, y, 'ro')
plt.show()

# %%
feature_importances_rf = pd.DataFrame(rf.feature_importances_,
                                   index = df4.drop(['AVG_READING_8_SCORE'],axis=1).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances_rf.head()
# Out:
#                          importance
# YEAR                       0.414224
# average_reveneue           0.144749
# STATE_REVENUE              0.101243
# INSTRUCTION_EXPENDITURE    0.070822
# GRADES_4_G                 0.060337

# %%
from sklearn.linear_model import Lasso, ElasticNet
clf = Lasso()

parameters = {'alpha': [0.00001,0.0001,0.001, 0.01],
              'tol': [0.00001,0.0001,0.001, 0.01]
             }

# Run the grid search
grid_obj = GridSearchCV(clf, parameters, cv=5)
grid_obj = grid_obj.fit(X, y)

# Set the clf to the best combination of parameters
clf = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
print('Params ',clf)
print('Score ',clf.score(X, y))
# Out:
# Params  Lasso(alpha=0.01, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.01, warm_start=False)
# Score  0.10756154864028544

# %%
Y_clf=clf.predict(X)
plt.plot(Y_clf, y, 'ro')
plt.show()

# %%
feature_importances_clf = pd.DataFrame(clf.coef_,
                                   index = df4.drop(['AVG_READING_8_SCORE'],axis=1).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances_clf.head(10)
# Out:
#                      importance
# YEAR                   0.192046
# STATE_MISSOURI         0.047810
# STATE_NEW_HAMPSHIRE    0.042076
# STATE_MINNESOTA        0.038010
# STATE_TEXAS            0.032499
# STATE_NEW_YORK         0.028208
# STATE_NEW_MEXICO       0.024305
# STATE_MISSISSIPPI      0.022754
# STATE_TENNESSEE        0.018674
# STATE_NEW_JERSEY       0.015883

# %%
eln = ElasticNet()

parameters = {'alpha': [0.00001,0.0001,0.001, 0.01],
              'l1_ratio': [0.0001,0.001,0.01, 0.1],
              'tol': [0.00001,0.0001,0.001, 0.01],
              'max_iter': [1000,2000,5000, 10000],
             }

# Run the grid search
grid_obj = GridSearchCV(eln, parameters, cv=5)
grid_obj = grid_obj.fit(X, y)

# Set the clf to the best combination of parameters
eln = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
print('Params ',eln)
print('Score ',eln.score(X, y))
# Out:
# Params  ElasticNet(alpha=0.01, copy_X=True, fit_intercept=True, l1_ratio=0.1,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.01, warm_start=False)
# Score  0.12292383331178647

# %%
Y_eln=eln.predict(X)
plt.plot(Y_eln, y, 'ro')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 15))
plt.plot(Y_eln, y, 'ro',label='Elastic Net')#red Elastic Net
plt.plot(Y_clf, y, 'bs',label='Lasso')#blue Lasso
plt.plot(Y_rf, y, 'g^',label='Random Forest')#green Random Forest
plt.plot([-5,2],[-5,2])#PREDICTION LIKE IT SHOUD BE
plt.legend()
plt.show()

# %%
feature_importances_eln = pd.DataFrame(eln.coef_,
                                   index = df4.drop(['AVG_READING_8_SCORE'],axis=1).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances_eln.head(10)
# Out:
#                             importance
# YEAR                          0.268796
# GRADES_KG_G                   0.224301
# INSTRUCTION_EXPENDITURE       0.216791
# STATE_TEXAS                   0.117399
# STATE_CALIFORNIA              0.103187
# STATE_MINNESOTA               0.072407
# STATE_MISSOURI                0.062666
# CAPITAL_OUTLAY_EXPENDITURE    0.061382
# STATE_MICHIGAN                0.053680
# STATE_NEW_JERSEY              0.050668

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.lineplot(x="YEAR", y="AVG_READING_8_SCORE", data=STATE)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.boxplot(x="AVG_READING_8_SCORE", y="STATE", data=STATE)

# %%
states=STATE.groupby(['STATE']).mean()
normalized_STATE=(states-states.mean())/states.std()
fig, ax = plt.subplots(figsize=(15, 15))
normalized_STATE['AVG_READING_8_SCORE'].plot(kind='bar');

# %% [raw]
# Abstract:
# In this work I'm concetrated on AVG_MATH_4_SCORE  and AVG_READING_8_SCORE . That's why i created a model for each one. I found the main influence on score  , everage money spend on one student (in my dataset asigned as AVERAGE) and the STATE where students are examed. Depanding on model  AVERAGE cash play high role .
